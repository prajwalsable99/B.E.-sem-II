# %%
#1 Morphology is the study of the way words are built up from smaller meaning bearing units. Study and understand the concepts of morphology by the use of add delete table

# %%
#sorce : https://nlp-iiith.vlabs.ac.in/exp/morphology/

# %%
from IPython.display import Image
Image(filename='Capture.JPG')

# %%
from IPython.display import Image
Image(filename='Capture2.JPG')
